# %%
import pandas as pd

# %%
hospitals = pd.read_csv("hospitals.csv")

# %%
hospitals.shape
# Out:
# (4772, 24)

# %%
hospitals.head()
# Out:
#                       Facility.Name Facility.City Facility.State  \
# 0  Southeast Alabama Medical Center        Dothan             AL
# 1     Marshall Medical Center South          Boaz             AL
# 2    Eliza Coffee Memorial Hospital      Florence             AL
# 3          Mizell Memorial Hospital           Opp             AL
# 4       Crenshaw Community Hospital       Luverne             AL
#
#   Facility.Type  Rating.Overall Rating.Mortality Rating.Safety  \
# 0    Government               2            Below         Above
# 1    Government               1            Below         Below
# 2    Government               3            Below         Above
# 3       Private               1             Same          Same
# 4   Proprietary               4             Same          None
#
#   Rating.Readmission Rating.Experience Rating.Effectiveness  ...  \
# 0              Below             Below                 Same  ...
# ...

# %%
len(hospitals['Facility.Name'].unique())
# Out:
# 4589

# %%
hospitals[hospitals[['Facility.Name','Facility.City','Facility.State']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Facility.Name, Facility.City, Facility.State, Facility.Type, Rating.Overall, Rating.Mortality, Rating.Safety, Rating.Readmission, Rating.Experience, Rating.Effectiveness, Rating.Timeliness, Rating.Imaging, Procedure.Heart Attack.Cost, Procedure.Heart Attack.Quality, Procedure.Heart Attack.Value, Procedure.Heart Failure.Cost, Procedure.Heart Failure.Quality, Procedure.Heart Failure.Value, Procedure.Pneumonia.Cost, Procedure.Pneumonia.Quality, Procedure.Pneumonia.Value, Procedure.Hip Knee.Cost, Procedure.Hip Knee.Quality, Procedure.Hip Knee.Value]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# #### Distinct Name-City-State : Verified

# %%
hospitals.columns.values
# Out:
# array(['Facility.Name', 'Facility.City', 'Facility.State',
#        'Facility.Type', 'Rating.Overall', 'Rating.Mortality',
#        'Rating.Safety', 'Rating.Readmission', 'Rating.Experience',
#        'Rating.Effectiveness', 'Rating.Timeliness', 'Rating.Imaging',
#        'Procedure.Heart Attack.Cost', 'Procedure.Heart Attack.Quality',
#        'Procedure.Heart Attack.Value', 'Procedure.Heart Failure.Cost',
#        'Procedure.Heart Failure.Quality', 'Procedure.Heart Failure.Value',
#        'Procedure.Pneumonia.Cost', 'Procedure.Pneumonia.Quality',
#        'Procedure.Pneumonia.Value', 'Procedure.Hip Knee.Cost',
#        'Procedure.Hip Knee.Quality', 'Procedure.Hip Knee.Value'],
#       dtype=object)

# %%
hospitals = hospitals[['Facility.Name', 'Facility.City', 'Facility.State',
       'Facility.Type', 'Rating.Overall','Rating.Safety','Rating.Readmission', 
       'Rating.Experience','Rating.Effectiveness', 'Rating.Timeliness', 
       'Procedure.Heart Attack.Cost', 'Procedure.Heart Attack.Quality']]

# %%
hospitals.rename(columns={
    'Facility.Name' : 'Hospital Name',
    'Facility.City' : 'City',
    'Facility.State' : 'State',
    'Facility.Type' : 'Hospital Type',
    'Rating.Overall' : 'Overall Treatment Rating',
    'Rating.Safety' : 'Treatment Safety Rating',
    'Rating.Readmission' : 'Treatment Readmissin Rating', 
    'Rating.Experience':'Average Patient Experience',
    'Rating.Effectiveness':'Treatment Effectiveness',
    'Rating.Timeliness' : 'Average Time to Cure', 
    'Procedure.Heart Attack.Cost' : 'Treatment Cost',
    'Procedure.Heart Attack.Quality': 'Treatment Quality'    
}, inplace=True)
# Out:
# C:\Users\as25160\Anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
hospitals.head()
# Out:
#                       Hospital Name      City State Hospital Type  \
# 0  Southeast Alabama Medical Center    Dothan    AL    Government
# 1     Marshall Medical Center South      Boaz    AL    Government
# 2    Eliza Coffee Memorial Hospital  Florence    AL    Government
# 3          Mizell Memorial Hospital       Opp    AL       Private
# 4       Crenshaw Community Hospital   Luverne    AL   Proprietary
#
#    Overall Treatment Rating Treatment Safety Rating  \
# 0                         2                   Above
# 1                         1                   Below
# 2                         3                   Above
# 3                         1                    Same
# 4                         4                    None
#
#   Treatment Readmissin Rating Average Patient Experience  \
# 0                       Below                      Below
# 1                       Below                       Same
# 2                       Above                      Below
# ...
